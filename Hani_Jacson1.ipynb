# %% [markdown]
# <a href="https://colab.research.google.com/github/Haniel-png/ip-2026-01/blob/main/Hani_Jacson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Questão1)
# Verifica Aprovação
#
# var
#
# N1, N2, N3 : real
#
# inicio
#
#  escreva(“Digite a primeira nota:”)
#  leia(N1)
#
#  escreva(“Digite a segunda nota:”)
#  leia(N2)
#
#  escreva(“Digite a terceira nota:”)
#  leia(N3)
#
# média <- (N1+N2+N3)/3
#
# escreval(Média do aluno é:”média)
#
#     se, média>= 6, então
#         escreval(“Status:Aprovado”)
#     senão,
#         escreval(“Status:Reprovado”)
#   fimse
#
# fimalgoritmo

# %% [markdown]
# Questão2)
#
# algoritmo
#
#
# var
#
#
#   ingressos: inteiro
#
#   porcentagem1, porcentagem2, porcentagem3,
#
#   porcentagem4: real
#
#   RendadoJogo: real
#
#
# inicio
#
#   escreva("Digite o número de ingressos:" )
#
#   leia(ingressos)
#
#
#   escreva("Digite a porcentagem de pessoas que
#   compraram ingresso na categoria Popular: " )
#
#   leia(porcentagem1)
#
#   escreva("Digite a porcentagem de pessoas que compraram ingresso na categoria Geral: " )
#
#   leia(porcentagem2)
#
#
# escreva("Digite a porcentagem de pessoas que compraram ingresso na categoria Arquibancada: " )
#
#  leia(porcentagem3)
#
#
# escreva("Digite a porcentagem de pessoas que compraram ingresso na categoria Cadeiras: " )
#
#  leia(porcentagem4)
#
# RendadoJogo <- (porcentagem1 * 1 + porcentagem2 * 5 + porcentagem3 * 10 + porcentagem4 * 20) * ingressos
#
#
# escreval(“A renda do jogo é:”, RendadoJogo)
#
#
# fimalgoritmo

# %% [markdown]
# Questão3)
# Composição
#
# var
#  soma: natural
#  n1, n2, n3: natural
#
# inicio
#
#    se n1<10 e n2<10 e n3<10, então
#
#  soma <- 100*n1+ 10*n2 + 1*n3
#
# escreva (“ O valor da composição é:” , soma)
#
# senão
#
#   escreva(“DÍGITO INVALIDO”)
# fimse
#
# fimalgoritmo

# %% [markdown]
# Questão4)
# Consumo de Energia
#
# var
#
#   salario: real
#
#   custo: real
#
#   consumo: real
#
#   custo1: real
#
# inicio
#
#   escreva(“Digite o seu salário:”)
#
#   leia(salario)
#
#   escreva(“Quantidade de KW gasto:”)
#
#   leia(consumo)
#
#   valordecadaKW <- (70*salario)/100*100
#
#   custo <- valordecadaKW*consumo
#
#   custo1 <- (custo*90)/100
#
#
# escreva(“Custo por KW: ”, valordecadaKW)
#
# escreva(“Custo do consumo:” custo)
#
# escreva(“Custo com o desconto:” custo1)
#
# fimalgoritmo

# %% [markdown]
# Questão5)
# algoritmo
#
#
# var
#
#
#   conta: inteiro
#
#   consumo: real
#
#   consumidor: caractere
#
#   valordaconta: real
#
#
# inicio
#
#
#   escreva("Digite a sua conta :")
#
#   leia(conta)
#
#   escreva("Digite o consumo de água:", "m³")
#
#   leia(consumo)
#
#
#   escreva("Digite o tipo de consumidor:")
#
#   leia(consumidor)
#
#
#   se (consumidor="R") entao
#
#     valordaconta <- 5 + 0.05*consumo
#
#     senao
#
#      se (consumidor="C") entao
#
#        se (consumo <= 80) entao
#
#         valordaconta <-  500
#
#          senao
#
#           valordaconta<- 500 + (0.25*consumo-80)
#
#            fimse
#
#             se (consumidor="I") entao
#
#              se(consumo <= 100) entao
#
#               valordaconta <- 800
#
#                senao
#
#                 valordaconta <- 800 + 0.04*(consumo - 100)
#
#          fimse
#
#         fimse
#
#      fimse
#
#   fimse
#
#
# fimalgoritmo

# %% [markdown]
# Questão6)
#
# algoritmo "Fahrenheit_para_Celsius"
#
#
# var
#    n, i: inteiro
#
#    f, c: real
#
#
# inicio
#
#
#    escreva("Digite o número de operações:")
#
#    leia(n)
#
#
#    para i de 1 ate n faca
#
#       escreva("Digite o valor em fahrenheit:")
#
#       leia(f)
#
#       c <- (f - 32) * 5 / 9
#
#       escreval(f:0:2, " FAHRENHEIT EQUIVALE A ",
#       c:0:2, " CELSIUS")
#
#    fimpara
#
#
# fimalgoritmo

# %% [markdown]
# Questão7)
#
# algoritmo "conversoes"
#
#
# var
#
#    f, c: real
#
#    polegadas, mm: real
#
#
# inicio
#
#    escreva("Digite a temperatura em fahrenheit:")
#
#    leia(f)
#
#    escreva("Digite o valor em polegadas:")
#
#    leia(polegadas)
#
#
#    c <- (5 * f - 160) / 9
#
#    mm <- polegadas * 25.4
#
#
#    escreval("O VALOR EM CELSIUS = ", c:0:2)
#
#    escreval("A QUANTIDADE DE CHUVA E = ", mm:0:2)
#
#
# fimalgoritmo

# %% [markdown]
# Questão8)
#
# algoritmo "custo_lata"
#
#
# var
#
#    r, a: real
#
#    pi, Ac, Al, At, custo: real
#
#
# inicio
#
#
#    pi <- 3.14159
#
#    escrva("Digite o raio em metros:")
#
#    leia(r)
#
#    escreva("Digite a altura em metros:")
#
#    leia(a)
#
#
#    Ac <- pi * r * r
#
#    Al <- 2 * pi * r * a
#
#    At <- 2 * Ac + Al
#
#
#    custo <- At * 100
#
#
#    escreva("O VALOR DO CUSTO E = ", custo:0:2, "\n")
#
#
# fimalgoritmo

# %% [markdown]
# Questão9)
#
# algoritmo "calculo_delta"
#
# var
#
# A, B, C, delta: real
#
# inicio
#
# leia(A)
#
# leia(B)
#
# leia(C)
#
# delta <- B * B - 4 * A * C
#
# escreva("O VALOR DE DELTA E = ", delta:0:2, "\n")
#
# fimalgoritmo

# %% [markdown]
# Questão10)
# algoritmo "determinante_matriz"
#
#
# var
#
#    a, b, c, d, det: real
#
#
# inicio
#
#    escreva("x11")
#
#    leia(a)
#
#    escreva("x12")
#
#    leia(b)
#
#    escreva("x21")
#
#    leia(c)
#
#    escreva("x22")
#
#    leia(d)
#
#
#    det <- a * d - b * c
#
#
#    escreva("O VALOR DO DETERMINANTE E = ",
#    det:0:2, "\n")
#
#
# fimalgoritmo

# %% [markdown]
# Questão11)
# algoritmo "divisivel_3_5"
#
#
# var
#
#    numero: inteiro
#
#
# inicio
#
#
#    escreva("Digite um numero inteiro: ")
#
#    leia(numero)
#
#
#    se (numero mod 3 = 0) e (numero mod 5 = 0) entao
#
#       escreva("O NUMERO E DIVISIVEL\n")
#
#    senao
#
#       escreva("O NUMERO NAO E DIVISIVEL\n")
#
#    fimse
#
#
# fimalgoritmo

# %% [markdown]
# Questão12)
# algoritmo "valor_charrete"
#
#
# var
#
#    horas, grupos, resto: inteiro
#
#    valor: real
#
#
# inicio
#
#
#    escreva("Digite a quantidade de horas de uso da
#
#    charrete: ")
#
#    leia(horas)
#
#
#    grupos <- horas div 3
#
#    resto <- horas mod 3
#
#
#    valor <- (grupos * 10) + (resto * 5)
#
#
#    escreva("O VALOR A PAGAR E = ", valor "\n")
#
#
# fimalgoritmo

# %% [markdown]
# Questão 13)
# var
#
#    nota: real
#
#    conceito: caractere
#
# inicio
#
#    escreva("Digite a nota do aluno: ")
#
#    leia(nota)
#
#    se nota >= 9.0 entao
#
#       conceito <- "A"
#
#     senao
#
#      se nota >= 7.5 entao
#
#       conceito <- "B"
#
#       senao
#
#        se nota >= 6.0 entao
#
#         conceito <- "C"
#
#         senao
#
#         conceito <- "D"
#
#      fimse
#
#     fimse
#
#    fimse
#
#    escreva("NOTA = ", nota:0:1, " CONCEITO = ",
#
#    conceito, "\n")
#
# fimalgoritmo

# %% [markdown]
# quetão14)
# algoritmo "volume_piramide"
#
# var
#    h, a: real
#    Ab, V: real
#
# inicio
#
#    escreva("Digite a altura e a aresta do hexagono: ")
#    leia(h, a)
#
#    Ab <- (3 * a * a * 3^0.5) / 2
#
#    V <- (Ab * h) / 3
#
#    escreva("O VOLUME DA PIRAMIDE E = ", V:0:2, " METROS CUBICOS")
#
# fimalgoritmo

# %% [markdown]
# Questão15)
# algoritmo "reajustedesalarios"
#
# var
#    salario:real
#    valortotal:real
# inicio
#
#    escreva("Digite o salário: ")
#    leia(salario)
#
#
#   se salario <= 300 entao
#    valortotal <- salario*1.5
#    senao
#    valortotal <- salario*1.3
#   fimse
#
#    escreva("Salário com reajuste:",valortotal)
#
# fimalgoritmo

# %% [markdown]
# Questão16)
#
# algoritmo "reajustedesalarios"
#
# var
#    salario:real
#    valortotal:real
# inicio
#
#    escreva("Digite o salário: ")
#    leia(salario)
#
#
#   se salario <= 300 entao
#    valortotal <- salario*1.5
#    senao
#    valortotal <- salario*1.3
#   fimse
#
#    escreva("Salário com reajuste:",valortotal)
#
# fimalgoritmo

# %% [markdown]
# Questão 17)
#
# algoritmo "seriedepares"
#
# var
#
#    x:inteiro
#    y:inteiro
#    n:inteiro
#
# inicio
#
#    escreva("Digite dois números x e y inteiro positivo: ")
#    leia(x,y)
#
#    se (x mod 2 = 0) entao
#
#    n <- x
#
#    para n de 1 ate y faca
#
#    escreva(x,"")
#
#    x <- x + 2
#
#    fimpara
#
#    senao
#
#    escreva("O primeiro número não é par")
#
#    fimse
#
#    fimalgoritmo

# %% [markdown]
# Questão 18)
#
# algoritmo "soma_pa"
#
# var
#
#    a, r, n: inteiro
#
#    termo, soma, i: inteiro
#
# inicio
#
#    escreva("Digite o primeiro termo, a razao e o
#
#    numero de termos: ")
#
#    leia(a, r, n)
#
#    soma <- 0
#
#    termo <- a
#
#    para i de 1 ate n faca
#
#       soma <- soma + termo
#
#       termo <- termo + r
#
#    fimpara
#
#    escreva(soma)
#
# fimalgoritmo

# %% [markdown]
# Questão 19)
#
# algoritmo "somatorio"
#
# var
#
#    n, i: inteiro
#
#    S: real
#
# inicio
#
#    escreva("Digite um numero inteiro positivo: ")
#
#    leia(n)
#
#    se n <= 1 entao
#
#       escreva("Numero invalido!)
#
#    senao
#
#       S <- 0
#
#       para i de 1 ate n faca
#
#          S <- S + (1 / i)
#
#       fimpara
#
#    escreva("O somatório será:",S:0:6)
#
#    fimalgoritmo

# %% [markdown]
# Quesão 20)
#
# algoritmo "conversao_de_tempo"
#
# var
#
#    h: inteiro
#
#    m: inteiro
#
#    s: inteiro
#
#    t: inteiro
#
# inicio
#
#    escreva("Digite as horas: ")
#
#    leia(h)
#
#    escreva("Digite os minutos: ")
#
#    leia(m)
#
#    escreva("Digite os segundos: ")
#
#    leia(s)
#
#    t <- 3600 * h + 60 * m + s
#
#    escreva("O TEMPO EM SEGUNDOS E = ", t, "s")
#
# fimalgoritmo
